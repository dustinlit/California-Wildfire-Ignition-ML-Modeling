# %% [markdown]
# <link rel="stylesheet" href="notebooks/styles.css">

# %% [markdown]
# <div class="title-wrap">
#   <h1 class="title-main" style="font-weight: bold; font-size: 2.65rem; margin-bottom: 0.5rem;">
#   Spatial Data Science Approaches to Wildfire Severity Modeling
# </h1>
# <h2 class="title-sub" style="font-style: italic; font-size: 1.8rem; margin-top: 0rem; margin-bottom: 0.2rem;">
#   A GIS‑Driven, Tree‑Based Machine Learning Analysis of California Wildfires
# </h2>
# </div>

# %% [markdown]
# # Module 6C: *Fire Damage Tuning*
# ##### Version Number: 4.0
# ---
# ### Contents
# > 1. *Random Forest*
# > 3. *XGBoost*
# > 4. *Export Optimum Configurations*
# ---
# ### Notes
# This module **automatically** finds the optimal configuration of models based on the average F1 score of all three categories.
#
# **WARNING** this module is very computation heavy
# - Start with a **baseline model** for comparison.
# - Test with multi-classification **tree-based models** (Random Forest, XGBoost) and LGBM.
# - Use kfold **cross-validation** to tune hyperparameters for each model.
# - Export optimal models
#
# ---
# ### Inputs

# %% [markdown]
# ---
# ### Outputs
#
# `model_parameters.csv` - optimal parameters for each of the three models
#
# ---
# ### User Created Dependencies

# %%
import os
import sys

# Allow import of custom modules from the parent directory
sys.path.append(os.path.abspath(os.path.join('..')))

from src.data_utils import *
from src.model_utils import *
from src.plot_utils import *

# %% [markdown]
# ---

# %% [markdown]
# ### Third Party Dependencies

# %%
# Core Python libraries
import numpy as np
import pandas as pd
import json

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Preprocessing and modeling
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
import xgboost as xgb

# Style
sns.set(style='whitegrid')
plt.rcParams["figure.dpi"] = 100

# %% [markdown]
# ---

# %% [markdown]
# ### Load File

# %%
X_damage = pd.read_csv('../data/processed/X_damage.csv')
y_damage = pd.read_csv('../data/processed/y_damage.csv').squeeze()

# %%
reform = pd.concat([X_damage,y_damage], axis=1)
subset = subset_df(reform, 'Target_Damage', 600)

y = subset['Target_Damage']
X = subset.drop(columns='Target_Damage')

# %% [markdown]
# ---

# %% [markdown]
# ## 1. Random Forest Classifier
#
# This section evaluates Hypertuning and class-balancing options for SciKitLearns **RandomForestClassifier**. Options are tested utilizing kfold validation.
# - `n_estimators` [50, 100, 150]
# - `max_depth` [5, 10, 15, 20]
# - `min_samples_split_values` = [2, 5, 10, 20, 50]
# - `max_features` ['sqrt', 'log2']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=14, stratify=y)

# %% [markdown]
# ### 1.1 Hyperparameter Tuning

# %% [markdown]
# #### Number of Estimators (n_estimators)

# %%
# Define parameter grid
estimators = [50, 100, 150]
optimum_n_estimator = test_values('RF','n_estimators',estimators,X_train, y_train,num_classes=2)
# Out:
# RF: n_estimators = 50 | Average F1 score = 0.8103
# RF: n_estimators = 100 | Average F1 score = 0.8103
# RF: n_estimators = 150 | Average F1 score = 0.8114

# %% [markdown]
# #### Maximum Tree Depth (max_depth)

# %%
# Define parameter grid
max_depth = [5, 10, 15, 20] 
optimum_max_depth = test_values('RF','max_depth',max_depth,X_train, y_train,num_classes=2)
# Out:
# RF: max_depth = 5 | Average F1 score = 0.8139
# RF: max_depth = 10 | Average F1 score = 0.8179
# RF: max_depth = 15 | Average F1 score = 0.8045
# RF: max_depth = 20 | Average F1 score = 0.8123

# %% [markdown]
# #### Maximum Features (max_features)

# %%
# Define parameter grid
max_features = ['sqrt', 'log2']
optimum_max_features = test_values('RF','max_features',max_features,X_train, y_train,num_classes=2)
# Out:
# RF: max_features = sqrt | Average F1 score = 0.8048
# RF: max_features = log2 | Average F1 score = 0.8114

# %% [markdown]
# #### Minimum Sample Split  (min_samples)

# %%
# Define parameter grid
min_samples_split_values = [2, 5, 10, 20, 50] 
optimum_min_samples_split = test_values('RF','min_samples_split',min_samples_split_values,X_train, y_train,num_classes=2)
# Out:
# RF: min_samples_split = 2 | Average F1 score = 0.8115
# RF: min_samples_split = 5 | Average F1 score = 0.8125
# RF: min_samples_split = 10 | Average F1 score = 0.8091
# RF: min_samples_split = 20 | Average F1 score = 0.8113
# RF: min_samples_split = 50 | Average F1 score = 0.8077

# %% [markdown]
# ### 1.2 Final Random Forest Model

# %%
RF_parameters = {
    'n_estimators': optimum_n_estimator,
    'max_depth': optimum_max_depth,
    'min_samples_split': optimum_min_samples_split,
    'max_features': optimum_max_features,
    'class_weight':'balanced'
}

pd.DataFrame([RF_parameters]).style \
    .hide(axis='index') \
    .set_caption("Optimum Random Forest Parameters")
# Out:
# <style type="text/css">
# </style>
# <table id="T_04c91">
#   <caption>Optimum Random Forest Parameters</caption>
#   <thead>
#     <tr>
#       <th id="T_04c91_level0_col0" class="col_heading level0 col0" >n_estimators</th>
#       <th id="T_04c91_level0_col1" class="col_heading level0 col1" >max_depth</th>
#       <th id="T_04c91_level0_col2" class="col_heading level0 col2" >min_samples_split</th>
#       <th id="T_04c91_level0_col3" class="col_heading level0 col3" >max_features</th>
#       <th id="T_04c91_level0_col4" class="col_heading level0 col4" >class_weight</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_04c91_row0_col0" class="data row0 col0" >150</td>
#       <td id="T_04c91_row0_col1" class="data row0 col1" >10</td>
#       <td id="T_04c91_row0_col2" class="data row0 col2" >5</td>
#       <td id="T_04c91_row0_col3" class="data row0 col3" >log2</td>
#       <td id="T_04c91_row0_col4" class="data row0 col4" >balanced</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ---

# %% [markdown]
# ## 3. XGBoost Classifier
#
# This section trains an XGBoost classifier using grid-based hyperparameter tuning and evaluates performance under different sampling strategies.

# %% [markdown]
# ### 3.2 Hyperparameter Tuning

# %% [markdown]
# #### n_estimators

# %%
n_estimators = [50, 100, 150, 200]
optimum_n_estimator = test_values('XGB','n_estimators', n_estimators, X_train, y_train,num_classes=2)
# Out:
# XGB: n_estimators = 50 | Average F1 score = 0.8162
# XGB: n_estimators = 100 | Average F1 score = 0.8194
# XGB: n_estimators = 150 | Average F1 score = 0.8192
# XGB: n_estimators = 200 | Average F1 score = 0.8148

# %% [markdown]
# #### learning_rate

# %%
learning_rates = [0.1, 0.2, 0.3, 0.4]
optimum_learning_rate = test_values('XGB','learning_rate', learning_rates, X_train, y_train,num_classes=2)
# Out:
# XGB: learning_rate = 0.1 | Average F1 score = 0.8190
# XGB: learning_rate = 0.2 | Average F1 score = 0.8181
# XGB: learning_rate = 0.3 | Average F1 score = 0.8078
# XGB: learning_rate = 0.4 | Average F1 score = 0.8150

# %% [markdown]
# #### max_depth

# %%
max_depths = [3, 4, 5, 6]
optimum_max_depth = test_values('XGB','max_depth', max_depths, X_train, y_train,num_classes=2)
# Out:
# XGB: max_depth = 3 | Average F1 score = 0.8183
# XGB: max_depth = 4 | Average F1 score = 0.8148
# XGB: max_depth = 5 | Average F1 score = 0.8182
# XGB: max_depth = 6 | Average F1 score = 0.8194

# %% [markdown]
# ### 3.3 Final XGBoost Model

# %%
XGB_parameters = {
    'objective': 'multi:softmax',
    'num_class': 3,
    'n_estimators': optimum_n_estimator,
    'max_depth': optimum_max_depth,
    'learning_rate': optimum_learning_rate,
    'verbosity': 0
}

pd.DataFrame([XGB_parameters]).style \
    .hide(axis='index') \
    .set_caption("Optimum XGBoost Parameters")
# Out:
# <style type="text/css">
# </style>
# <table id="T_2b0b2">
#   <caption>Optimum XGBoost Parameters</caption>
#   <thead>
#     <tr>
#       <th id="T_2b0b2_level0_col0" class="col_heading level0 col0" >objective</th>
#       <th id="T_2b0b2_level0_col1" class="col_heading level0 col1" >num_class</th>
#       <th id="T_2b0b2_level0_col2" class="col_heading level0 col2" >n_estimators</th>
#       <th id="T_2b0b2_level0_col3" class="col_heading level0 col3" >max_depth</th>
#       <th id="T_2b0b2_level0_col4" class="col_heading level0 col4" >learning_rate</th>
#       <th id="T_2b0b2_level0_col5" class="col_heading level0 col5" >verbosity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_2b0b2_row0_col0" class="data row0 col0" >multi:softmax</td>
#       <td id="T_2b0b2_row0_col1" class="data row0 col1" >3</td>
#       <td id="T_2b0b2_row0_col2" class="data row0 col2" >100</td>
#       <td id="T_2b0b2_row0_col3" class="data row0 col3" >6</td>
#       <td id="T_2b0b2_row0_col4" class="data row0 col4" >0.100000</td>
#       <td id="T_2b0b2_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ---

# %% [markdown]
# ## 4. Export Data

# %%
model_params_damage = {
    'Random Forest': RF_parameters,
    'XGBoost': XGB_parameters
}

# %%
# Save to CSV

with open('model_parameters_damage.json', 'w') as f:
    json.dump(model_params_damage, f, indent=4)
    
print("All datasets saved successfully to ../data/processed/")
# Out:
# All datasets saved successfully to ../data/processed/
