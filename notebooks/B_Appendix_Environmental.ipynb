# %% [markdown]
# <h2 style="color:red; text-align:left; font-size:50px; font-weight:bold; text-decoration:underline;">
#   Cal Fire
# </h2>
#
# ## Appendix B: *Environmental*
# - *Version Number: 1.0*
# ---
# ### Contents
# > 1. *Exploration*
# > 2. *Visualization*
# ---
# ### Notes
# ---
# ### Inputs
# > - **gridMET**: <https://www.climatologylab.org/gridmet.html
# > - **CDEC** Data:
# >   - <https://flowwest.github.io/CDECRetrieve/articles/CDECRetrieve.html>
# >   - <https://data.ca.gov/dataset/national-hydrography-data-nhd-and-3dhp/resource/a189d4e0-9115-4441-9b82-42a0237f2a77>
# >   - <https://cdec.water.ca.gov/dynamicapp/wsSensorData>
# > - **CIMIS** Stations: <https://cimis.water.ca.gov/>
# >   - raw dataset = '.../data/raw/i04_CIMIS_Weather_Stations.csv'
# > - **CIMIS** Weather Data: <https://cimis.water.ca.gov/>
# >   - raw dataset = '.../data/raw/CIMISdata.csv'
# > - **CDFW Regions**: <https://data.ca.gov/dataset/cdfw-regions>
# >   - raw shapefile = '.../data/raw/CDFW_Regions.zip'
# ---
# ### Variables Defined in this Module:
# > `Precipitation` `Evapotranspiration` `Wind` `Humidity` `Temperature`
# ---
# ### Outputs
# - `Environmental.csv` - cleaned dataset of environmental variables
# ---
# ### User Created Dependencies
# ---

# %% [markdown]
# ### Third Party Dependencies
# ---

# %% [markdown]
# ## Data Processing
#
# *Located in:*
# > - *notebooks/01_Fire_Damage_Processing.ipynb*
# > - *notebooks/02_Weather_Data_Processing.ipynb*
# > - *notebooks/A_Appendix.pynb*
#
# - ArcGIS, constructed an equally spaced grid of sampling points for overall better coverage.
# - Merged detailed fire records with sampling points via intersect spatial join.
# - Imputed missing values for weather stations.
